# %%
text = "hello world"
print(text)
print(text.upper())
print(text.lower())
print(text.title())
print(text.replace("world", "python"))
# Out:
# hello world
# HELLO WORLD
# hello world
# Hello World
# hello python

# %%
text = "python is the best language"
print(len(text))
# Out:
# 27

# %%
first= "hello"
second= "python"
print(first + second)
print(8+5)
print('8' + '5')
# Out:
# hellopython
# 13
# 85

# %%
text= "python"
print(text[0])
print(text[2])
print([-1])
print([-2])
# Out:
# p
# t
# [-1]
# [-2]

# %%
#question 1
#write two python program that takes two variables(a&b), prints the results, and prints the result again without using a third variable.

a=10
b=5
print(a)
print(b)
a,b= b,a
print(a)
print(b)
# Out:
# 10
# 5
# 5
# 10

# %%
# question 2
#write a program that takes a first and last name in lower case, and prints only the initialsin uppercase.

firstname= ("arafat")
lastname=("ibrahim")
print(f"{firstname[0].upper()}{lastname[0].upper()}")
# Out:
# AI

# %%
# question 3
#write a program that takes a string and checks if it consist only od digit(0-9). note: your solution should check for both all-numeric and alphanumeric.

text=("abcde12345")
print(text)
print(text.isnumeric())
# Out:
# abcde12345
# False

# %%
# question 4
# write a program that takes a word and prints the number of characters in it.

text=("communication")
print(len(text))
# Out:
# 13

# %%
#questiopn 5
#write a program that takes a sentence and converts it to title case, where the first letter of each word is capitalized.

text= ("man go")
print(text.title())
# Out:
# Man Go

# %%
#question 6
# write a program that takes a stringand prints the first character and the last character.

text= ("shutdown")
print(f"{text[0]}{text[-1]}")
# Out:
# sn

# %%
name= ("saheed")
age= 23
print(f"my name is{name} and i am {age} years olds")
# Out:
# my name issaheed and i am 23 years olds

# %%
text= ("building")
print(text[-3].upper()+ text[-1].upper())
# Out:
# IG

# %%
name= ("arafat")
fellow = ("AI")
host=("webfala")
print(f"my name is {name} i am a {fellow}fellow and it is host by {host}")
# Out:
# my name is arafat i am a AIfellow and it is host by webfala

# %%
n=234
new_n= float(n)
print(new_n)
# Out:
# 234.0

# %%
f= "dgeyyf"
type(f)
# Out:
# str

# %%
5%2
# Out:
# 1

# %%
def add(musaraff, qoseem):
    return musarraf + qoseem

# %%
f=[1,2,3,4,5]
m=[1,3,5,6,7]
n=f+m
f+=m
print(n)
# Out:
# [1, 2, 3, 4, 5, 1, 3, 5, 6, 7]

# %%
l= [[1,2,3],[4,5,6]]
print( [1,2,3]+[4,5,6])
print(l[0][1])
print(l[1][2])
# Out:
# [1, 2, 3, 4, 5, 6]
# 2
# 6

# %%
names = ['Abiola', 'Halimah', 'Zainab', 'Esther', 'Carina', 'Salamat', 'Fumi', 
         'Jamilah', 'Lola', 'Hannah'] 
print(names)
names[1]= 'benjamin'
print(names)
# Out:
# ['Abiola', 'Halimah', 'Zainab', 'Esther', 'Carina', 'Salamat', 'Fumi', 'Jamilah', 'Lola', 'Hannah']
# ['Abiola', 'benjamin', 'Zainab', 'Esther', 'Carina', 'Salamat', 'Fumi', 'Jamilah', 'Lola', 'Hannah']

# %%
fruits = ["apple", "banana"] 
print(fruits)
# Out:
# ['apple', 'banana']

# %%
fruits.append("cherry")
print(fruits)
# Out:
# ['apple', 'banana', 'cherry']

# %%
fruits = ["apple", "banana"] 
print(fruits)
# Out:
# ['apple', 'banana']

# %% [markdown]
# more_fruits=["cherry","mango"]
# fruits.extend(more_fruits)
# print(fruits)

# %%
items=['detergent','milk','shoe','fruit']
print(items)
# Out:
# ['detergent', 'milk', 'shoe', 'fruit']

# %%
items.insert(2, 'beef')
print(items)
# Out:
# ['detergent', 'milk', 'beef', 'shoe', 'fruit']

# %%
fruits= ["apple","banana","cherry","apple"]
print(fruits)
# Out:
# ['apple', 'banana', 'cherry', 'apple']

# %%
fruits.remove("banana")
print(fruits)
# Out:
# ['apple', 'cherry', 'apple']

# %%
names = ['Abiola', 'Halimah', 'Zainab', 'Esther', 'Carina', 'Salamat', 'Fumi', 
         'Jamilah', 'Lola', 'Hannah'] 
print(names)
# Out:
# ['Abiola', 'Halimah', 'Zainab', 'Esther', 'Carina', 'Salamat', 'Fumi', 'Jamilah', 'Lola', 'Hannah']

# %%
names = ['Abiola', 'Halimah', 'Zainab', 'Esther', 'Carina', 'Salamat', 'Fumi', 
         'Jamilah', 'Lola', 'Hannah'] 
print(names)
# Out:
# ['Abiola', 'Halimah', 'Zainab', 'Esther', 'Carina', 'Salamat', 'Fumi', 'Jamilah', 'Lola', 'Hannah']

# %%
names.pop()
print(names)
# Out:
# ['Abiola', 'Halimah', 'Zainab', 'Esther', 'Carina', 'Salamat', 'Fumi', 'Jamilah', 'Lola']

# %%
names.pop(4)
print(names)
# Out:
# ['Abiola', 'Halimah', 'Zainab', 'Esther', 'Salamat', 'Fumi', 'Jamilah', 'Lola']

# %%
print(names.index('Salamat'))
# Out:
# 4

# %%
numbers = [1, 2, 2, 3, 4, 2] 
print(numbers.count(2))
# Out:
# 3

# %%
names = ['Abiola', 'Halimah', 'Zainab', 'Esther', 'Carina', 'Salamat', 'Fumi', 
         'Jamilah', 'Lola', 'Hannah'] 
print(names)
# Out:
# ['Abiola', 'Halimah', 'Zainab', 'Esther', 'Carina', 'Salamat', 'Fumi', 'Jamilah', 'Lola', 'Hannah']

# %%
names.reverse()
print(names)
# Out:
# ['Hannah', 'Lola', 'Jamilah', 'Fumi', 'Salamat', 'Carina', 'Esther', 'Zainab', 'Halimah', 'Abiola']

# %%
names = ['Abiola', 'Halimah', 'Zainab', 'Esther', 'Carina', 'Salamat', 'Fumi', 
         'Jamilah', 'Lola', 'Hannah'] 
print(names)

print(reversed(names))
# Out:
# ['Abiola', 'Halimah', 'Zainab', 'Esther', 'Carina', 'Salamat', 'Fumi', 'Jamilah', 'Lola', 'Hannah']
# ...

# %%
cars = ['Tesla', 'Honda', 'Benz', 'Ford', 'Chevi', 'Audi', 'Toyota'] 
print(cars)
# Out:
# ['Tesla', 'Honda', 'Benz', 'Ford', 'Chevi', 'Audi', 'Toyota']

# %%
cars.sort()
print(cars)
# Out:
# ['Audi', 'Benz', 'Chevi', 'Ford', 'Honda', 'Tesla', 'Toyota']

# %%
cars.sort(reverse=True)
print(cars)
# Out:
# ['Toyota', 'Tesla', 'Honda', 'Ford', 'Chevi', 'Benz', 'Audi']

# %%
cars = ['Tesla', 'Honda', 'Benz', 'Ford', 'Chevi', 'Audi', 'Toyota'] 
print(cars)
print(sorted(cars))
# Out:
# ['Tesla', 'Honda', 'Benz', 'Ford', 'Chevi', 'Audi', 'Toyota']
# ['Audi', 'Benz', 'Chevi', 'Ford', 'Honda', 'Tesla', 'Toyota']

# %%
names_copy=names.copy()
print(names_copy)
# Out:
# ['Abiola', 'Halimah', 'Zainab', 'Esther', 'Carina', 'Salamat', 'Fumi', 'Jamilah', 'Lola', 'Hannah']

# %%
names_copy.append("ramat")
print(names_copy)
# Out:
# ['Abiola', 'Halimah', 'Zainab', 'Esther', 'Carina', 'Salamat', 'Fumi', 'Jamilah', 'Lola', 'Hannah', 'ramat']

# %%
names_copy.clear()
print(names_copy)
# Out:
# []

# %%
names = ['Abiola', 'Halimah', 'Zainab', 'Esther', 'Carina', 'Salamat', 'Fumi', 
         'Jamilah', 'Lola', 'Hannah'] 
print(names)
# Out:
# ['Abiola', 'Halimah', 'Zainab', 'Esther', 'Carina', 'Salamat', 'Fumi', 'Jamilah', 'Lola', 'Hannah']

# %%
names_copy=names.copy()
print(names_copy)
# Out:
# ['Abiola', 'Halimah', 'Zainab', 'Esther', 'Carina', 'Salamat', 'Fumi', 'Jamilah', 'Lola', 'Hannah']

# %%
numbers= [1, 2, 5, 10, 20]
print (numbers)
print(numbers.[0])
    [4])
# Out:
#   Cell In[46], line 4
#     [4])
#        ^
# SyntaxError: unmatched ')'

# %%
name_guests= ("Adeola", "Arafat", "salamat")
print(f"{name_guests[0]} is invited to dinner im my house")
print(f"{name_guests[1]} is invited to dinner in my house")
print(f"{name_guests[2]} is invited to dinner in my house")

print(f"{"Adeola"} will not be available")

new_guests= "zainaib"
print(f"{new_guests} is now invited")
print(f"{name_guests[1]} is invited to dinner in my house")
print(f"{name_guests[2]} is invited to dinner in my house")

# %%
x=(5,)
print(x)
type(x)

# %%
empty_tuple=()
single_element_tuple=(5,)
nums=5,6,5
numbers=(1,2,3,4,5)
fruits=("apple","banana","cherry")
mixed=(1,"hello",3.5,True)
nested_tuple=((1,2,3),(4,5,6))
print(numbers)

# %%
names=('abiola','halima','zainab','esther','adijat')
names[4]='lola'

# %%
# If you need a modified version, you can convert the tuple to a list, modif
names = ('Abiola', 'Halimah', 'Zainab', 'Esther', 'Adijat')
print(names)
names_list = list(names) # Convert to list
names_list[4] = 'Lola' # Modify the list
names = tuple(names_list) # Convert back to tuple
print(names)

# %% [markdown]
# # hello

# %% [markdown]
# ## hello

# %%
empty_set= set()
fruits={"apple","banana","cherry"}
numbers={7,3,9,1,2,3,4,5}
mixed={1,"hello",3.5, True}
xyz={5,8,4}
print(numbers)
print(xyz)

# %%
# an empty string is false
# zero (0)is equal to false
# one(1) is equal to true
fruits={"apple","banana"}
fruits.add("cherry")
print(fruits)
fruits.update(("mangoes","pineapple"))
print(fruits)

# %%
fruits={"apple","banana","cherry"}
fruits.pop()
print(fruits)

# %%
set1={1,2,3}
set2={3,4,5}
result=set1.union(set2)
print(result)

# %%
# Alternatively, use the | operator (pipe operator)
result=set1|set2
print(result)

# %%
set1={1,2,3,4}
set2={3,4,5,6}
result=set1.intersection(set2)
print(result)

# %%
# Alternatively,use the & operator
result= set1&set2
print(result)

# %%
set1={1,2,3,4}
set2={3,4,5,6}
result=set1.difference(set2)
print(result)

# %%
# Alternatively, usethe - operator
result=set1-set2
print(result)

# %%
set1={1,2,3,4}
set2={3,4,5,6}
result=set1.symmetric_difference(set2)
print(result)

# %%
# Alternatively, use the ^ operator.
result= set1^set2
print(result)

# %%
# one= is asigning
# two== is comparison

set1={1,2}
set2={1,2,3,4}
print(set1.issubset(set2))

# %%
# Alternatively, use the <= operator.
print(set1<=set2)

# %%
set1={1,2}
set2={1,2,3,4}
print(set2.issuperset(set1))

# %%
# Alternatively, use the >=: 
print(set2>=set1)

# %%
# US is universal set
us= {1,2,3,4,5,6,7,8}
set1={1,2,3}
set2={4,5,6}
print(set1.isdisjoint(set2))

# %%
fruits={"apple","banana","cherry"}
print("banana" in fruits)

# %%
# A dictionary is created using curly braces {} or the dict() constructor.
# Creating a dictionary
# empty_dict = {} # Empty dictionary

person = {
"name": "Tomi",
"age": 20,
"city": "Ilorin"
}
numbers = {1: "One", 2: "Two", 3: "Three"} # Keys can be integers
mixed_keys = {"name": "Zainab", 42: "Answer", (1, 2): "Tuple as key"}
print(person['name'])

# %%
# Accessing Values Using Keys
person = {
"name": 'Tomi',
"age": 15,
"city": "Ilorin",
'name': 'Salamat',
}
print(person["name"])
print(person["age"])

# %%
# If a key does not exist, it raises a KeyError:

print(person["salary"])

# %%
# Using get() to Avoid Errors
# The get() method returns None if the key is missing, avoiding KeyError
print(person.get("name"))
print(person.get("salary"))
print(person.get("salary","unavailable"))

# %%
# Adding New Key-Value Pairs

student= {"name": "abiola","age": 15}
print(student)
student["city"]= "ilorin"
print(student)

# %%
# updating an existingkey's value

student['age'] = 30
print(student)

# %%
# 5. pop() – Removes a Key and Returns Its Value
#If the key does not exist, it raises a KeyError.

person={"name": 'lola',"age": 15, "city":'ilorin'}
print(person)
person.pop("age")
print(person)

# %%
# popitem() – Removes the Last Inserted Key-Value Pair

person.popitem()
print(person)

# %%
# del – Deletes a Specific Key
# in dictionary pop() and delete have thesame function
person={"name":"nafisat","age": 22,"city":"lagos"}
print(person)
del person["city"]
print(person)
# Out:
# {'name': 'nafisat', 'age': 22, 'city': 'lagos'}
# {'name': 'nafisat', 'age': 22}

# %%
# clear() – Removes All Key-Value Pairs

person = {"name": "Adeola", "age": 15, "city": "Ilorin"}
print(person)
person.clear()
print(person)
# Out:
# {'name': 'Adeola', 'age': 15, 'city': 'Ilorin'}
# {}

# %%
# keys() – Returns All Keys

person = {"name": "Ramat", "age": 15, "city": "Ilorin"}
print(person)

print(person.keys())

# %%
# values()- Returns all values
print(person.values())

# %%
#items() – Returns Key-Value Pairs as Tuples

print(person)
print(person.items())

# %%
# update() – Merges Two Dictionaries
#n Updates the dictionary with key-value pairs from another dictionary

person = {"name": "Jemilah", "age": 15}
print(person)
new_data = {"city": "Ilorin", "age": 25}
person.update(new_data)
print(person)

# %%
# using in keyword

person= {"name": "jane", "age": 20}

print(person)
print("name" in person)
print("salary" in person)

# %%
# copy() – Creates a Copy

person = {"name": "Halimat", "age": 15, "city": "Ilorin"}
print(person)
copy_dict = person.copy()
print(copy_dict)

# %%
#len() – Returns the Number of Key-Value Pairs

print(len(person))

# %%
# Challenge
student = {
"name": "Funmi",
"info": {"age": 20, "hobbies": ['reading', 'travelling', 'cooking']}
}
# print out the second hobby

print(student['info']["hobbies"][1])

# %%
# Using the input() Function
# The input() function:
# Reads a line of text entered by the user.
# Always returns the value as a string.
# Can be stored in a variable for further use.

xyz= input("enter anything")
print(xyz)

# %%
name = input("Enter your name: ")
print(f"Hello, {name}!")

# %%
age = input('enter your age')
print(age)

# %%
age= input("enter your age:")
print(type(age))
print(f"You are {age} years old.")

# %%
age= int(input("enter your age:"))
print(type(age))
print(f"You are {age} years old.")

# %%
height= float(input('enter your height:'))
print(type(height))
print(f"my height is {height}m")

# %%
height= float(input('enter your height:'))
print(type(height))
print(f"my height is {height}m")

# %%
#Working with Set - 10 points
#Two groups of students enrolled in different courses.
#Inputs:
python = {"Adeola", "Zainab", "Funmi", "Tomi", "Abiola", "Nofisat"}
ml = {"Abiola", "Halimat", "Funmi", "Tomi", "Arafat"}

#a). Find students in both courses (b). Find all students(c). Find students only in Python

print(python&ml)
print(python|ml)
print(python-ml)

# %%
#Website Visitor Tracker - 10 points You are tracking unique visitors to a website. Given the names of the visitors ['Abiola', 'Halimah', 'Zainab', 'Esther', 'Lola', 'Carina', 'Salamat', 'Funmi', 'Zainab', 'Jamilah', 'Lola', 'Hannah', 'Esther'].

#Print all visitors Print the unique visitors in alphabetical order

visitors= ['Abiola', 'Halimah', 'Zainab', 'Esther', 'Lola', 'Carina', 'Salamat', 'Funmi', 'Zainab', 'Jamilah', 'Lola', 'Hannah', 'Esther']
print(visitors) 
unique_visitors= list(visitors)
print(unique_visitors)
unique_visitors.sort()
print(unique_visitors)

# %%
# Tuple - 10 points
#A flight booking system stores passenger details as a tuple: ("Benjamin Ogbona", "AB123", "London")

#Print the passenger's name
#You noticed the surname was entered wrongly, correct the surname
#Print the passenger's details

passenger=  ("Benjamin Ogbona", "AB123", "London")
print(passenger[0])

# %%
# Dictionary (Company Structure) - 20 points
#You work for a company and you have the task of storing, updating and deleting the company's employee data in a dictionary (database). Each employee has a first name, last name, gender and role, and there are 4 employees.

#a) Create a dictionary to store all 4 employees in a variable named 'webfala'.
#b) Print every info about the second employee
#b) Some time later, the 3rd employee was promoted to the CTO, update the role of the 3rd employee and then print the final data.

# %%
xyz=input('enter full name:')
print(xyz.split())

# %%
import math

# %%
#math module
print(math.pi)
print(math.e)
print(math.inf)
print(-math.inf)
# Out:
# 3.141592653589793
# 2.718281828459045
# inf
# -inf

# %%
math.sqrt(27)
# Out:
# 5.196152422706632

# %%
math.pow(2, 3)

# %%
#single* is multiplication
#double**is power
2*2
2**4

# %%
# finding absolute value
math.fabs(-10.5)

# %%
# floor and ceil
# math.floor(x):rounds downtothe nearest integer
#math.ceil(x): rounds upto the nearestinteger

math.floor(4.7)

# %%
math.ceil(4.1)

# %%
#logaritrthmic functions

print(math.log(10))
print(math.log(10, 2))

# %%
# trigonometric functions
math.sin(90)

# %%
math.cos(90)

# %%
print(math.tan(math.pi/4))   # divide pi  4 then calculate it tan

# %%
# there is also inverse trigonometric functon

print(math.asin(1))
print(math.acos(0))
print(math.atan(1))

# %%
# alias means nickname and it can be anything in python e.g math as m

import math as m

# %%
m.pi
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[52], line 1
# ----> 1 m.pi
#
# AttributeError: 'list' object has no attribute 'pi'

# %%
# the random module

import random

# %%
random_num=random.random()
print(random_num)
# Out:
# 0.2423773435198061

# %%
random_num=random.randint(1,10)
print(random_num)
# Out:
# 3

# %% [raw]
# random_num=random.uniform(1, 5)
# print(random_num)

# %%
names=["hanna", "abiola", "zainab"]
random_name=random.choice(names)
print(random_name)
# Out:
# zainab

# %%
names=["hanna", "abiola", "zainab"]
random.shuffle(names)
print(names)
# Out:
# ['zainab', 'abiola', 'hanna']

# %%
range(1, 15)

# %%
ramdon_num= random.randint(1, 20)**2
print(random_num)
# Out:
# 3

# %%
a=10
b=3
print(a+b)
print(a-b)
print(a*b)
print(a/b)
print(a//b)
print(a%b)
print(a**b)
print(f'{a} divide {b} is {a//b},and the reminderis {(a%b)}')
# Out:
# 13
# 7
# 30
# 3.3333333333333335
# 3
# 1
# 1000
# 10 divide 3 is 3,and the reminderis 1

# %%
x=10
y= 5
print(x==y)
print(x!=y)
print(x>y)
print(x<y)
print(x<=y)
print(x>=y)
# Out:
# False
# True
# True
# False
# False
# True

# %%
x= 5
y= 10
z= 15
print(x<y or x>z)
print(x>5 and y<10)
print(x>5 or y>10)
print(not(x>5))
# Out:
# True
# False
# False
# True

# %%
# bitwise operation

#bitwise operators perform operations on binary numbers.

a=5
b=3
print(a&b)
print(a|b)
print(a^b)
# Out:
# 1
# 7
# 6

# %%
balance=190000
credit=20000
balance += credit
print(balance)
balance -= credit
print(balance)
balance *= credit
print(balance)
balance /= credit
print(balance)
# Out:
# 210000
# 190000
# 3800000000
# 190000.0
